# %%
# 10^6 rolls
import numpy as np


count = 0
   
i = 0
while (i < 1000000):
    i = i + 1
    a = np.random.randint(1,7)
    c = np.random.randint(1,7)
    if (a==6):
        if (c==6):
            count = count + 1
   


print(count)
probability = count/1000000
print(probability*100)
# Out:
# 27427
# 2.7427

# %%
#single die
import numpy as np


a = np.random.randint(1,7)
c = np.random.randint(1,7)

print(a,c)
# Out:
# 5 6

# %%
import matplotlib.pyplot as plt

N = 1000
a = 3
c = 101234265791147
m = 424503530013579
x = 2
results = []

for i in range(N):
    x = (a*x+c)%m
    y = x*10/m - 5
    results.append(y)
    




plt.plot(results,"o")

plt.show()
plt.hist(results)
# Out:
# (array([ 104.,  105.,  103.,  118.,   92.,   84.,  110.,   90.,   95.,   99.]),
#  array([ -4.98518787e+00,  -3.98715359e+00,  -2.98911932e+00,
#          -1.99108504e+00,  -9.93050762e-01,   4.98351481e-03,
#           1.00301779e+00,   2.00105207e+00,   2.99908634e+00,
#           3.99712062e+00,   4.99515490e+00]),
#  <a list of 10 Patch objects>)
